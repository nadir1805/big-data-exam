# %%
import paho.mqtt.client as mqtt 
from random import randrange, uniform
import time

mqttBroker ="broker.mqttdashboard.com" 

client = mqtt.Client("Producer")
client.connect(mqttBroker) 

while True:
    temp = uniform(0.0, 40.0)
    Process_temp = uniform(0, 40)
    #productid = uniform(-30,10)
    #speed = uniform(0.0,12.0)
    rotation_speed = uniform(0.0,70.0)
    couple = uniform(100,125)
    vibration = uniform(0,14)
    pression = uniform(0,14)
    tool_wear = uniform(0,14)


    
    
    
    client.publish("TEMPERATURE", temp)
    print("Just published " + str(temp) + " to topic TEMPERATURE")
    time.sleep(10)
    
    client.publish("PROCESS", Process_temp)
    print("Just published " + str(Process_temp) + "PROCESS")
    time.sleep(10)
    
    client.publish("ROTATION", rotation_speed)
    print("Just published " + str(rotation_speed) + " to topic ROTATION")
    time.sleep(10)
    
    client.publish("COUPLE", couple)
    print("Just published " + str(couple) + " to topic COUPLE")
    time.sleep(10)
    
    client.publish("VIBRATION", vibration)
    print("Just published " + str(vibration) + " to topic VIBRATION")
    time.sleep(10)

    
    client.publish("PRESSION", pression)
    print("Just published " + str(pression) + " to topic PRESSION")
    time.sleep(10)
    
    client.publish("TOOL", tool_wear)
    print("Just published " + str(tool_wear) + " to topic TOOL")
    time.sleep(10)
# Out:
# Just published 35.65979014538585 to topic TEMPERATURE
# Just published 29.582975265267166PROCESS
# Just published 22.655431288014846 to topic ROTATION
# Just published 108.56476043337241 to topic COUPLE
# Just published 3.9375642390141965 to topic VIBRATION
# Just published 4.514258002287793 to topic PRESSION
# Just published 9.038388090421803 to topic TOOL
# Just published 0.8232209572933336 to topic TEMPERATURE
# Just published 32.64134659448552PROCESS
# Just published 40.191550818659884 to topic ROTATION
# Just published 123.57271691271404 to topic COUPLE
# Just published 6.181687899528656 to topic VIBRATION
# Just published 4.3293461810196305 to topic PRESSION
# Just published 10.177897199989014 to topic TOOL
# Just published 1.5738185771366675 to topic TEMPERATURE
# Just published 21.976896197618974PROCESS
# Just published 13.779427420449315 to topic ROTATION
# Just published 102.60068681894829 to topic COUPLE
# Just published 9.535848911586118 to topic VIBRATION
# ...
